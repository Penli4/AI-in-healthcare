# %%
import numpy as np
import pandas as pd

# %%
with open("lab1.txt", 'w') as file:
  file.write("The dataset is the Cleveland Heart Disease dataset taken from the UCI repository. The dataset consists of 303 individuals’ data. There are 14 columns in the dataset(which have been extracted from a larger set of 75). No missing values. The classification task is to predict whether an individual is suffering from heart disease or not. (0: absence, 1: presence)")

# %%
with open("lab1.txt", "r") as file:
    content = file.read()
    print(content)
# Out:
# The dataset is the Cleveland Heart Disease dataset taken from the UCI repository. The dataset consists of 303 individuals’ data. There are 14 columns in the dataset(which have been extracted from a larger set of 75). No missing values. The classification task is to predict whether an individual is suffering from heart disease or not. (0: absence, 1: presence)

# %%
data = {
    "Name": ["A", "B", "C"],
    "Age": [20, 21, 22]
}

df = pd.DataFrame(data)

print(df)
print(df.head(1))
print(df.shape)
# Out:
#   Name  Age
# 0    A   20
# 1    B   21
# 2    C   22
#   Name  Age
# 0    A   20
# (3, 2)

# %%
numbers = np.array([10, 20, 30, 40, 50])

print(numbers)
print(numbers.mean())
print(numbers.max())
print(numbers.min())
# Out:
# [10 20 30 40 50]
# 30.0
# 50
# 10

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 20, 15, 30, 25]

plt.plot(x, y)
plt.xlabel("X values")
plt.ylabel("Y values")
plt.title("Simple Line Graph")
plt.show()
